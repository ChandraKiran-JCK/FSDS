# %%
# String -> enclosed inside "" / ''

# %%
s = "Chandra"
type(s)
# Out:
# str

# %%
# internally indexex are created for the string both in forward(0,1,...) and backward(-1,-2,....) directions.

# %%
s[0]
# Out:
# 'C'

# %%
s[1]
# Out:
# 'h'

# %%
s[2]
# Out:
# 'a'

# %%
s[3]
# Out:
# 'n'

# %%
s[-1]
# Out:
# 'a'

# %%
s[-2]
# Out:
# 'r'

# %%
s[-3]
# Out:
# 'd'

# %%
# if index does not exists then we get error as string index out of range
s[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # if index does not exists then we get error as string index out of range
# ----> 2 s[20]
#
# IndexError: string index out of range

# %%
a = "my name is sudh"

# %%
a
# Out:
# 'my name is sudh'

# %%
# string slicing 
# str[start_index : end_index : step]
# default start_index = 0 , default end_index = string length , default step = 1
# end_index is excluded
a[:]
# Out:
# 'my name is sudh'

# %%
a[0:10] # [0 - 10)
# Out:
# 'my name is'

# %%
b = "ineuron"

# %%
b[0:3] #[0 - 3)
# Out:
# 'ine'

# %%
# end_index is excluded

# %%
b[0:3]
# Out:
# 'ine'

# %%
# end_index can be out of range
b[0:300]
# Out:
# 'ineuron'

# %%
# scaling in strings (always pick with in boundaries of values)
# travelling direction == stepping direction then string slice.
# travelling direction != stepping direction then empty string.

# %%
b[0:300:1]
# Out:
# 'ineuron'

# %%
b[0:300:2]
# Out:
# 'iern'

# %%
b[0:100:-1]
# Out:
# ''

# %%
b[-1:-4:1]
# Out:
# ''

# %%
b[-1:-10:-1]
# Out:
# 'norueni'

# %%
b[-1:-1:1]
# Out:
# ''

# %%
b[0:-10:1]
# Out:
# ''

# %%
b[-5:5:-1]
# Out:
# ''

# %%
b[-2:]
# Out:
# 'on'

# %%
b[-2:-1]
# Out:
# 'o'

# %%
b[::-1]
# Out:
# 'norueni'

# %%
# default step step size is 1 , if step size is mentioned -1 
# if not mentioned then default start_index = -1 , default end_index = -string_length
b[::-1]
# Out:
# 'norueni'

# %%
b
# Out:
# 'ineuron'

# %%
b[-5:5]
# Out:
# 'eur'

# %%
# str1 + str2 = str3.
# str1 * n = repeat str1 for n times.

# %%
a = "abc"
b = "def"

# %%
a+b
# Out:
# 'abcdef'

# %%
a*3
# Out:
# 'abcabcabc'

# %%
# length of the string
# len(str)
len(a)
# Out:
# 3

# %%
len(a*3)
# Out:
# 9

# %%
a.find('a') # found string returns index
# Out:
# 0

# %%
a.find('i') # not found returns -1
# Out:
# -1

# %%
a.find('ab')
# Out:
# 0

# %%
a
# Out:
# 'abc'

# %%
a.find('bc')
# Out:
# 1

# %%
a = 'my name is chandra'

# %%
a
# Out:
# 'my name is chandra'

# %%
a.count('a') # occurences of the given string
# Out:
# 3

# %%
a.count(' c')
# Out:
# 1

# %%
a.find(' c')
# Out:
# 10

# %%
a.count('x')
# Out:
# 0

# %%
a
# Out:
# 'my name is chandra'

# %%
a.split() # splits the string based on the sep(default is ' ') and returns a list and this list length == count(sep)+1.
# Out:
# ['my', 'name', 'is', 'chandra']

# %%
a.split('a')
# Out:
# ['my n', 'me is ch', 'ndr', '']

# %%
a.split('x')
# Out:
# ['my name is chandra']

# %%
type(a.split())
# Out:
# list

# %%
l = a.split()
l
# Out:
# ['my', 'name', 'is', 'chandra']

# %%
l[0]
# Out:
# 'my'

# %%
l[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 l[4]
#
# IndexError: list index out of range

# %%
l[0:4]
# Out:
# ['my', 'name', 'is', 'chandra']

# %%
l[2:7]
# Out:
# ['is', 'chandra']

# %%
a
# Out:
# 'my name is chandra'

# %%
a.split('a')
# Out:
# ['my n', 'me is ch', 'ndr', '']

# %%
a.split('an')
# Out:
# ['my name is ch', 'dra']

# %%
a.split('andra')
# Out:
# ['my name is ch', '']

# %%
a
# Out:
# 'my name is chandra'

# %%
a.upper() # converts into upper case
# Out:
# 'MY NAME IS CHANDRA'

# %%
a1 = "ChandraKiran"

# %%
a1
# Out:
# 'ChandraKiran'

# %%
a1.swapcase() # swaps the cases
# Out:
# 'cHANDRAkIRAN'

# %%
a1
# Out:
# 'ChandraKiran'

# %%
a1.lower() # converts into lower case
# Out:
# 'chandrakiran'

# %%
a1
# Out:
# 'ChandraKiran'

# %%
a2 = 'chandra kiran jami'

# %%
a2
# Out:
# 'chandra kiran jami'

# %%
a2.title() # each word first letter turns into capital/upper case
# Out:
# 'Chandra Kiran Jami'

# %%
a3 = a2.title()
a3
# Out:
# 'Chandra Kiran Jami'

# %%
a3.lower()
# Out:
# 'chandra kiran jami'

# %%
a2
# Out:
# 'chandra kiran jami'

# %%
a2.capitalize() # only the first letter turns into capital/upper case
# Out:
# 'Chandra kiran jami'

# %%
str1 = "abcd"
str2 = "12345"

# %%
str1.join(str2) # b/w all the characters in str2 append str1
# Out:
# '1abcd2abcd3abcd4abcd5'

# %%
" ".join('chandra')
# Out:
# 'c h a n d r a'

# %%
str1
# Out:
# 'abcd'

# %%
str1 = "  chandra   "
str1
# Out:
# '  chandra   '

# %%
str1.strip() # trims the spaces on both ends
# Out:
# 'chandra'

# %%
str1.rstrip() # trims the spaces on the right hand side
# Out:
# '  chandra'

# %%
str1.lstrip() # trims the spaces on the left hand side
# Out:
# 'chandra   '

# %%
s = 'chandra'
s
# Out:
# 'chandra'

# %%
s.replace('a' , 'x') # replaces the old value with new value
# Out:
# 'chxndrx'

# %%
s.replace('k' , 'x')
# Out:
# 'chandra'

# %%
"chandra\tkiran".expandtabs() # expands the tabs in the string if exists
# Out:
# 'chandra kiran'

# %%
# in-build functions starting with isFunctionName -> o/p will be boolean type

# %%
s = "chandra123"

# %%
s.isupper()
# Out:
# False

# %%
s.islower()
# Out:
# True

# %%
s.upper().isupper()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
" ".isspace()
# Out:
# True

# %%
" chn an".isspace()
# Out:
# False

# %%
s.isdigit()
# Out:
# False

# %%
"1234".isdigit()
# Out:
# True

# %%
"123cd".isdigit()
# Out:
# False

# %%
s
# Out:
# 'chandra123'

# %%
s.endswith('123')
# Out:
# True

# %%
s.endswith('3')
# Out:
# True

# %%
s.endswith('4')
# Out:
# False

# %%
s.startswith('c')
# Out:
# True

# %%
s.startswith('cha')
# Out:
# True

# %%
s.startswith('chn')
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s.title().istitle()
# Out:
# True

# %%
# LIST -> enclosed inside [].
# collection of heterogenous data.
# index based access.

# %%
l1 = ['chandra' , 3.14 , 100 , 5+7j , True , "rtyu"]
type(l1)
# Out:
# list

# %%
l1
# Out:
# ['chandra', 3.14, 100, (5+7j), True, 'rtyu']

# %%
l1[0]
# Out:
# 'chandra'

# %%
l1[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 l1[10]
#
# IndexError: list index out of range

# %%
l1[-1]
# Out:
# 'rtyu'

# %%
l1[3]
# Out:
# (5+7j)

# %%
len(l1) # length of the list
# Out:
# 6

# %%
l1[0:3]
# Out:
# ['chandra', 3.14, 100]

# %%
l1[0:100]
# Out:
# ['chandra', 3.14, 100, (5+7j), True, 'rtyu']

# %%
l1[::-1] # list reverse
# Out:
# ['rtyu', True, (5+7j), 100, 3.14, 'chandra']

# %%
l1
# Out:
# ['chandra', 3.14, 100, (5+7j), True, 'rtyu']

# %%
l1[-1:6]
# Out:
# ['rtyu']

# %%
# extract 'a' from the 1st element of the list 
l1[0][2]
# Out:
# 'a'

# %%
l1[3].real
# Out:
# 5.0

# %%
l1[3].imag
# Out:
# 7.0

# %%
l1 = ['abc' , 2.43 , 45]
l2 = ['ade' , 5+6j , True]

# %%
l1
# Out:
# ['abc', 2.43, 45]

# %%
l2
# Out:
# ['ade', (5+6j), True]

# %%
l1 + l2 # list concatenation
# Out:
# ['abc', 2.43, 45, 'ade', (5+6j), True]

# %%
l1 * 4
# Out:
# ['abc', 2.43, 45, 'abc', 2.43, 45, 'abc', 2.43, 45, 'abc', 2.43, 45]

# %%
# list1 + list2 = list 3.
# list * n = repeat list for n times.

# %%
l1 = ['chandra' , 3.14 , 100 , 5+7j , True , "rtyu"]
l1
# Out:
# ['chandra', 3.14, 100, (5+7j), True, 'rtyu']

# %%
# replace 'chandra' with 200 value 
l1[0] = 200
l1
# Out:
# [200, 3.14, 100, (5+7j), True, 'rtyu']

# %%
# list is mutable
# string is immutable

# %%
str1 = l1[5]
str1
# Out:
# 'rtyu'

# %%
str1[0] = 'R'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 str1[0] = 'R'
#
# TypeError: 'str' object does not support item assignment

# %%
l1
# Out:
# [200, 3.14, 100, (5+7j), True, 'rtyu']

# %%
len(l1)
# Out:
# 6

# %%
# in operation -> returns boolean value
200 in l1
# Out:
# True

# %%
'rtyu' in l1
# Out:
# True

# %%
4.13 in l1
# Out:
# False

# %%
100 in l1
# Out:
# True

# %%
# in-build functions

# %%
l2
# Out:
# ['ade', (5+6j), True]

# %%
# append(data) -> appends given data at the end
l2.append(100)
l2
# Out:
# ['ade', (5+6j), True, 100]

# %%
# pop(index) -> remove the data at the given index default is -1
l2.pop()
# Out:
# 100

# %%
l2
# Out:
# ['ade', (5+6j), True]

# %%
l2.pop(1)
# Out:
# (5+6j)

# %%
l2
# Out:
# ['ade', True]

# %%
# insert(index,element) -> inserts the given element at given index if index exists 
l2.insert(0,100)
l2
# Out:
# [100, 'ade', True]

# %%
l2.insert(1 , [23,4.13,'cha'])

# %%
l2
# Out:
# [100, [23, 4.13, 'cha'], 'ade', True]

# %%
l2[::-1]
# Out:
# [True, 'ade', [23, 4.13, 'cha'], 100]

# %%
l2
# Out:
# [100, [23, 4.13, 'cha'], 'ade', True]

# %%
l2.reverse() # permanent reverse
l2
# Out:
# [True, 'ade', [23, 4.13, 'cha'], 100]

# %%
l2
# Out:
# [True, 'ade', [23, 4.13, 'cha'], 100]

# %%
l2[2][0]
# Out:
# 23

# %%
# count(element) - occurences of the element
l2.count(100)
# Out:
# 1

# %%
l2.count(4.13)
# Out:
# 0

# %%
l2.count('ade')
# Out:
# 1

# %%
# extend function -> used to append collection of elements one by one.
l2
# Out:
# [True, 'ade', [23, 4.13, 'cha'], 100]

# %%
l2.append([1,2,3,4])

# %%
l2
# Out:
# [True, 'ade', [23, 4.13, 'cha'], 100, [1, 2, 3, 4]]

# %%
l2.extend([1,2,3,4]) # extend(collection)
l2
# Out:
# [True, 'ade', [23, 4.13, 'cha'], 100, [1, 2, 3, 4], 1, 2, 3, 4]

# %%
# -> add an element to list 
# append(element)
# insert(index,element)
# extend(collection) -> concatination of list with the given collection

# %%
a1 = [1,2,[3,4,5]]
a2 = [6,7,8]
a1+a2
# Out:
# [1, 2, [3, 4, 5], 6, 7, 8]
