# %%
# string - collection of characters.
# list - collection of heterogenous elements.

# tuple -> enclosed inside () 
# heterogenous elements can be store 
# index based access
t = (10 , "chandra" , 3.14 , 1+2j , True)
type(t)
# Out:
# tuple

# %%
t
# Out:
# (10, 'chandra', 3.14, (1+2j), True)

# %%
t[0]
# Out:
# 10

# %%
t[-1]
# Out:
# True

# %%
t[3]
# Out:
# (1+2j)

# %%
# tuple slicing == list/string slicing

# %%
t
# Out:
# (10, 'chandra', 3.14, (1+2j), True)

# %%
t[0:2]
# Out:
# (10, 'chandra')

# %%
t[-1:-3] # empty tuple
# Out:
# ()

# %%
t[-1:-3:-1]
# Out:
# (True, (1+2j))

# %%
t[::-1]
# Out:
# (True, (1+2j), 3.14, 'chandra', 10)

# %%
t[0:300:2]
# Out:
# (10, 3.14, True)

# %%
# list is mutable 
# string is immutable
# tuple is immutable

# %%
t
# Out:
# (10, 'chandra', 3.14, (1+2j), True)

# %%
t[0]
# Out:
# 10

# %%
t[0] = 100
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 t[0] = 100
#       2 t
#
# TypeError: 'tuple' object does not support item assignment

# %%
# tuple1 + tuple2 = tuple3
t1 = (1,2,3,4)
t2 = (4,5,6)
t1 + t2
# Out:
# (1, 2, 3, 4, 4, 5, 6)

# %%
# tuple * n -> repeat the tuple for n times
t2 * 3
# Out:
# (4, 5, 6, 4, 5, 6, 4, 5, 6)

# %%
# in-built functions

# %%
t
# Out:
# (10, 'chandra', 3.14, (1+2j), True)

# %%
t.count(3.14) # count(element) -> occurences of the element
# Out:
# 1

# %%
t.count(20)
# Out:
# 0

# %%
t.count(True)
# Out:
# 1

# %%
t.index(3.14) # index(element) -> found return index else error
# Out:
# 2

# %%
t.index(20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 t.index(20)
#
# ValueError: tuple.index(x): x not in tuple

# %%
# we have only 2 in-built funtions in tuple (count() , index())

# %%
# convert tuple into list 
l = list(t)
l
# Out:
# [10, 'chandra', 3.14, (1+2j), True]

# %%
t = (1 , 2 , 3 , (4 , 5.15 , 6) , "ch" , [2,4,True])
t
# Out:
# (1, 2, 3, (4, 5.15, 6), 'ch', [2, 4, True])

# %%
type(t)
# Out:
# tuple

# %%
t[5]
# Out:
# [2, 4, True]

# %%
t[5][1] = 10
t
# Out:
# (1, 2, 3, (4, 5.15, 6), 'ch', [2, 10, True])

# %%
l
# Out:
# [10, 'chandra', 3.14, (1+2j), True]

# %%
t2 = tuple(l)
t2
# Out:
# (10, 'chandra', 3.14, (1+2j), True)

# %%
# set -> enclosed inside {}
# collection of unique elements all the duplicates will be removed.
# heterogenous elements can be store except list.
# index based access is "not allowed" as they are un-ordered.

# %%
s = {0 , 1 , 2 , 3 , "cha" , True , False , 3.14 , 4+5j , 3 , 2 , 1 , True , 3.14 , 3 , 2 , 1}
s
# Out:
# {(4+5j), 0, 1, 2, 3, 3.14, 'cha'}

# %%
s1 = {}
type(s1)
# Out:
# dict

# %%
s2 = {1,2,3,4}
type(s2)
# Out:
# set

# %%
# {} -> empty is considered as dict bcz dict/set have same notation.
# {} + elements -> set
# {} + key:value pair -> dict

# %%
l = list(s) # convertin set to list
l
# Out:
# [0, 1, 2, 3, 3.14, 'cha', (4+5j)]

# %%
# in-built functions

# %%
s
# Out:
# {(4+5j), 0, 1, 2, 3, 3.14, 'cha'}

# %%
s.add(100) # add(element) - inserts the element into the set
s
# Out:
# {(4+5j), 0, 1, 100, 2, 3, 3.14, 'cha'}

# %%
s.add("chandra")
s
# Out:
# {(4+5j), 0, 1, 100, 2, 3, 3.14, 'cha', 'chandra'}

# %%
s.add([1,2,3]) # list insertion is not possible
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 s.add([1,2,3]) # list insertion is not possible
#       2 s
#
# TypeError: unhashable type: 'list'

# %%
s.add(t1) # tuple insertion is possible
s
# Out:
# {(1, 2, 3, 4), (4+5j), 0, 1, 100, 2, 3, 3.14, 'cha', 'chandra'}

# %%
s
# Out:
# {(1, 2, 3, 4), (4+5j), 0, 1, 100, 2, 3, 3.14, 'cha', 'chandra'}

# %%
s.remove(2) # remove(element) - if exists remove the element from the set else keyerror.
s
# Out:
# {(1, 2, 3, 4), (4+5j), 0, 1, 100, 3, 3.14, 'cha', 'chandra'}

# %%
s.remove(4)
s
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 s.remove(4)
#       2 s
#
# KeyError: 4

# %%
s
# Out:
# {(1, 2, 3, 4), (4+5j), 0, 1, 100, 3, 3.14, 'cha', 'chandra'}

# %%
s.discard(1) # discard(element) - if exists remove the element from the set else no error.
s

# %%
s

# %%
s.discard(1)
s

# %%
# add(element) -> element != list
# remove(element) -> error if element does not exists
# discard(element) -> no error

# %%
# dict - enclosed inside {}
# collection of key:value pair data
# heterogenous elements can be stored

# %%
d = {}
type(d)

# %%
d = {
    1 : "chandra" , 
    2 : "1234"
}
# 1 , 2 -> keys
# "chandra" , "1234" -> values

d

# %%
d1 = {
    "key1" : 1234 , 
    "key2" : "nksjn" , 
    3 : "chandra" , 
    4+5j : True , 
    "key5" : [1,2,3,4,5]
}

d1

# %%
# key based access

# %%
d1["key1"]

# %%
d1[3]

# %%
d1[4+5j]

# %%
d1["key6"]

# %%
# if key is repeated then value gets overridden.
# so ensure keys must be unique.

# %%
d1 = {
    "key1" : 45 , 
    "key2" : True , 
    "key3" : 4+5j ,
    "key1" : "chandra"
}

d1

# %%
d1["key1"]

# %%
d2 = {
    "name" : "Chandra" , 
    "age" : 25 , 
    "email" : "chandra@gmail.com" , 
    "male" : True , 
    "marks" : [10,20,15,10,15] , 
    "key1" : (1,2,3,4,1,2,3,4) , 
    "key2" : {1,2,3,1,2,3,1,2,23,3,3} , 
    "key3" : {
        1 : "one" , 
        2 : "two" , 
        3 : "three"
    }
}

d2

# %%
d2["key2"]

# %%
type(d2["key2"])

# %%
type(d2["key3"])

# %%
d2["key3"]

# %%
d2["key3"][2]

# %%
# in-built functions

# %%
d2.keys() # list of all the keys

# %%
d2.values() # list of all the values

# %%
d2.items() # list of tuple of each key:value pair

# %%
# while assigning if key does not exists then new key:value pair will created with the key & assigned value 
d1

# %%
d1["key4"] = [1,2,3,4]
d1

# %%
d1[10] = "new key"
d1

# %%
d1["key1"] = "kiran"
d1

# %%
# delete a key 
del d1[10]
d1

# %%
del d1["key1"]
d1

# %%
del d1 # deletes the complete dict
d1

# %%
d1 = {'key1': 'chandra',
 'key2': True,
 'key3': (4+5j),
 'key4': [1, 2, 3, 4],
 10: 'new key'}
d1

# %%
# key != list/set/dict
# key must be immutable

# %%
d1[[1,2]] = "vcdsvc"
d1

# %%
d1[{3,4,3,4}] = "erty"
d1

# %%
d1[(1,2)] = "vhgjb"
d1

# %%
d1

# %%
# in-built functions
# get(key) -> if key exists return value else blank

# %%
d1.get(10)

# %%
d1.get((1,2))

# %%
d1.get("key4")

# %%
d1.get("key5")

# %%
d1

# %%
d

# %%
# update(dict) -> appends the given dict
d.update(d1)
d

# %%
# dict1 + dict2 -> error
