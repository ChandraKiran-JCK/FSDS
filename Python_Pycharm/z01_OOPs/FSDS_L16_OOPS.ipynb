# %%
from Python import my_module

"""
1. Constructor detailed
2. types of Constructor (default constructor | zero argument constructor | parametarized constructor)
3. Constructor overloading
4. class variables
5. __main__ -> super class of all the classes , internally each class has a __main__
"""
"""
[CLASS] <--> SELF <--> [PROPERTIES/TASKS <--> OBJECT]
Self (pointer) -> binds object to class
"""
# Out:
# '\n[CLASS] <--> SELF <--> [PROPERTIES/TASKS <--> OBJECT]\nSelf (pointer) -> binds object to class\n'

# %%
"""
1. Create a class for dictionary parsing
a. WAF to return all the keys.
b. WAF to return all the values.
c. WAF to take key and value pair from user to add in dictionary.
d. WAF to take DICT from user as an input and parse that dictionary.
e. WAF to throw/raise an exception if i/p is not a dictionary.
"""

class dict_parser :

    # class properties
    dict_obj : dict = {}

    #while creating an object, the user has to pass a dictionary
    def __init__(self , dict1:dict):
        self.dict_obj = dict1


    # a
    def getKeys(self):
        """
        This is a function to return all the keys
        """
        # self.getValues() to call function inside another function.
        return self.dict_obj.keys()

    # b
    def getValues(self):
        """
        This is a function to return all the values
        """
        return self.dict_obj.values()

    # c
    def add(self , key , value):
        """
        This is a function to add the value to the dictionary and return the new dictionary
        """
        self.dict_obj[key] = value
        return self.dict_obj

    # d , e
    def parseUserDict(self , user_dict : dict):
        """
        take DICT from the user as an input and parse that dictionary. throw/raise an exception if i/p is not a dictionary.
        """
        if type(user_dict) != dict:
            raise ValueError("User dictionary is not a dictionary" , user_dict)
        else :
            print("User dictionary is valid")
            print("Keys :" , user_dict.keys())
            print("Values :" , user_dict.values())

# %%
d1 = {
    1 : "Chandra" ,
    2 : "Kiran" ,
    3 : "Jami" ,
    "gh" : [1,2,3,4,5] ,
    4 : [5,6,7,8,9] ,
}

l1 = [1,2,3,4,5]

# %%
d1_obj = dict_parser(d1)
print(d1_obj)
# Out:
# <__main__.dict_parser object at 0x000001CDF5765400>

# %%
d1_obj.getKeys()
# Out:
# dict_keys([1, 2, 3, 'gh', 4])

# %%
d1_obj.getValues()
# Out:
# dict_values(['Chandra', 'Kiran', 'Jami', [1, 2, 3, 4, 5], [5, 6, 7, 8, 9]])

# %%
d1_obj.parseUserDict(d1)
# Out:
# User dictionary is valid
# Keys : dict_keys([1, 2, 3, 'gh', 4])
# Values : dict_values(['Chandra', 'Kiran', 'Jami', [1, 2, 3, 4, 5], [5, 6, 7, 8, 9]])

# %%
d2 = d1_obj.add("fgh" , (1,2,3,4,5))
d2
# Out:
# {1: 'Chandra',
#  2: 'Kiran',
#  3: 'Jami',
#  'gh': [1, 2, 3, 4, 5],
#  4: [5, 6, 7, 8, 9],
#  'fgh': (1, 2, 3, 4, 5)}

# %%
d1_obj.parseUserDict(d2)
# Out:
# User dictionary is valid
# Keys : dict_keys([1, 2, 3, 'gh', 4, 'fgh'])
# Values : dict_values(['Chandra', 'Kiran', 'Jami', [1, 2, 3, 4, 5], [5, 6, 7, 8, 9], (1, 2, 3, 4, 5)])

# %%
d1_obj.parseUserDict(l1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 d1_obj.parseUserDict(l1)
#
# Cell In[33], line 49, in dict_parser.parseUserDict(self, user_dict)
#      45 """
#      46 take DICT from the user as an input and parse that dictionary. throw/raise an exception if i/p is not a dictionary.
#      47 """
#      48 if type(user_dict) != dict:
# ---> 49     raise ValueError("User dictionary is not a dictionary" , user_dict)
#      50 else :
#      51     print("User dictionary is valid")
#
# ValueError: ('User dictionary is not a dictionary', [1, 2, 3, 4, 5])

# %%
d1_obj.parseUserDict(d2)
# Out:
# User dictionary is valid
# Keys : dict_keys([1, 2, 3, 'gh', 4, 'fgh'])
# Values : dict_values(['Chandra', 'Kiran', 'Jami', [1, 2, 3, 4, 5], [5, 6, 7, 8, 9], (1, 2, 3, 4, 5)])

# %%
from my_module import dict_parser

# %%
d3_obj = dict_parser({
    1 : "Chandra" ,
    2 : "Kiran" ,
    3 : [1,2,3,4,5] ,
    4 : 10
})

# %%
d3_obj.getKeys()
# Out:
# dict_keys([1, 2, 3, 4])

# %%
d3_obj.getValues()
# Out:
# dict_values(['Chandra', 'Kiran', [1, 2, 3, 4, 5], 10])

# %%
d3_obj.add(10 , 4+5j)
# Out:
# {1: 'Chandra', 2: 'Kiran', 3: [1, 2, 3, 4, 5], 4: 10, 10: (4+5j)}

# %%
d3_obj.getKeys()
# Out:
# dict_keys([1, 2, 3, 4, 10])

# %%
d3_obj.getValues()
# Out:
# dict_values(['Chandra', 'Kiran', [1, 2, 3, 4, 5], 10, (4+5j)])

# %%
"""
Assignment:
1. Create our own package for all the list functions.
2. Create our own package for all the tuple functions.
3. Create our own package for all the dictionary functions.
4. Create our own package for all the set functions.

Guidelines:
1. use exception handling.
2. dont use print() instead use logger for every activity performed.
"""
# Out:
# '\nAssignment:\n1. Create our own package for all the list functions.\n2. Create our own package for all the tuple functions.\n3. Create our own package for all the dictionary functions.\n4. Create our own package for all the set functions.\n'
