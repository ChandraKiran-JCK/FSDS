# %%
# Lecture 2
1. Tech stack & roles in data industry (Big data vs Data analytics vs Data science)
        Data Science - Python/Math/ML/DL/NLP/RL/Cloud/Ops ....
2. What is AI -> AI is complete system which can solve a problem by taking some intelligent decisions.
3. Real life usage of AI (projects)
        Ex: Uber/Youtube/Gmail ....
4. Anaconda Installation.
