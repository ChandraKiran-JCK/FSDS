# %%
1+1
# Out:
# 2

# %%
# jupyter flow of code execution

jupyter editor(notebook) -> anaconda -> python(interpreter) -> execute -> o/p -> jupyter editor

# %%
pwd
# Out:
# 'E:\\FSDS\\Python'

# %%
# Assignments & submissions

# %%
# 01_Python Programming use cases :
# 1. System Programming
# 2. GUI application 
# 3. Web Scrapping
# 4. DB's handling
# 5. Numeric/Scientific programming
# 6. Game development
# 7. Image processing
# 8. Robotics

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
"""
shift + enter -> for execution
shift + tab -> description of any function 
"""
# Out:
# '\nshift + enter -> for execution\nshift + tab -> description of any function \n'

# %%
print("my name is chandu")
# Out:
# my name is chandu

# %%
1+2
# Out:
# 3

# %%
3/7
# Out:
# 0.42857142857142855

# %%
# python supports scripting & oops (modular)

# %%
# Variables: is a container name which holds data (RAM)
a = 10
abc = 722423

# a , abc -> variables
# 10 , 722423 -> data

# %%
a
# Out:
# 10

# %%
abc
# Out:
# 722423

# %%
# type() - inbuilt function, which return the type of data that a variable is holding.
type(a)
# Out:
# int

# %%
type(abc)
# Out:
# int

# %%
b = 4.35
type(b)
# Out:
# float

# %%
c1 = 3+5j

# %%
c1
# Out:
# (3+5j)

# %%
type(c1)
# Out:
# complex

# %%
c = "chandra"
type(c)
# Out:
# str

# %%
e = 'chandu'

# %%
e
# Out:
# 'chandu'

# %%
c
# Out:
# 'chandra'

# %%
# string storing = "" or '' o/p will in ''

# %%
g = True

# %%
type(g)
# Out:
# bool

# %%
# bool -> boolean(True/False)

# %%
# Notes :
# 1. variable name can be alphaNumeric but it should not start with a digit.
# 2. symbols are not allowed to use except _ , $ symbol for varibale names.

# %%
a = 10
b = "chandu"
c = 4.13
d = 5+7j
e = True

# %%
a
# Out:
# 10

# %%
b
# Out:
# 'chandu'

# %%
c
# Out:
# 4.13

# %%
d
# Out:
# (5+7j)

# %%
e
# Out:
# True

# %%
a,b,c,d,e = 20 , "chandra" , 3.14 , 2+3j , False

# %%
a
# Out:
# 20

# %%
b
# Out:
# 'chandra'

# %%
c
# Out:
# 3.14

# %%
d
# Out:
# (2+3j)

# %%
e
# Out:
# False

# %%
# in 2nd approach mapping is done b/w varaiables & data. so, varaibles count === data count else error(not enough/too many)

# %%
# complex number 
c2 = 3+4j
print(c2.real)
print(c2.imag)
# Out:
# 3.0
# 4.0

# %%
# tab -> for in-built functions list.

# %%
b
# Out:
# 'chandra'

# %%
b1 = b.upper()
b1
# Out:
# 'CHANDRA'

# %%
# String concatination 
# Type casting

a = "abc"
b = 4 

# a+b -> TypeError: can only concatenate str (not "int") to str
# so typecast 4 to string 
a + str(b)
# Out:
# 'abc4'

# %%
# for Boolean data True == 1 , False == 0
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
False + False
# Out:
# 0

# %%
True - True
# Out:
# 0

# %%
1 + True
# Out:
# 2

# %%
# user input 
input()
# Out:
#  1234567890
# '1234567890'

# %%
a1 = input()
# Out:
#  1234567890

# %%
a1
# Out:
# '1234567890'

# %%
# return type of input() is always string

# %%
a2 = input()
# Out:
#  20

# %%
type(a2)
# Out:
# str

# %%
a2 = int(a2)
type(a2)
# Out:
# int

# %%
a2 + 10
# Out:
# 30

# %%
a3 = input()
# Out:
#  erx

# %%
type(a3)
# Out:
# str

# %%
# a3 = int(a3) # ValueError: invalid literal for int() with base 10: 'erx'
