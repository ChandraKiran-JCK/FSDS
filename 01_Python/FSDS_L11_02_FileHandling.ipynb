# %%
# File handling

# %%
# %pwd 
# present working directory/folder
# Out:
# 'E:\\FSDS\\Python'

# %%
# %ls 
# list of files/folders in pwd
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 08-12-2025  08:57    <DIR>          .
# 06-12-2025  11:12    <DIR>          ..
# 08-12-2025  08:57    <DIR>          .ipynb_checkpoints
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
# %dirs 
# folders in pwd
# Out:
# []

# %%
# open(
#     file, -> file name (if file-name exists open that file , else create a file with the given name)
#     mode='r', -> default is r(read mode) , w(write mode with replacement) , r+/w+(read + write mode) , a(write mode with appending)
#     buffering=-1,
#     encoding=None,
#     errors=None,
#     newline=None,
#     closefd=True,
#     opener=None,
# )

# mode:
# 'r'       open for reading (default)
# 'w'       open for writing, truncating the file first
# 'x'       create a new file and open it for writing
# 'a'       open for writing, appending to the end of the file if it exists
# 'b'       binary mode
# 't'       text mode (default)
# '+'       open a disk file for updating (reading and writing)

# %%
# writing to a file

# %%
f = open(
        file="text1.txt" ,
        mode="w" # write operation on file with content replacement
)

# %%
# %ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 08-12-2025  08:57    <DIR>          .
# 06-12-2025  11:12    <DIR>          ..
# 08-12-2025  08:57    <DIR>          .ipynb_checkpoints
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
f = open(
    file="text1.txt" ,
    mode="w"
)

# %%
f.write(
    "This is my first file operation using python"
)
f.flush()
f.close()

# write(content) -> return the total length of the content written to the file.
# WHEN EVER WE WRITE WE HAVE TO FLUSH & CLOSE IT FOR COMPLETION.

# %%
# open the file in the system to view the results.

# %%
f1 = open(
    file="text2.txt" ,
    mode="w"
)

# %%
f1.write(
    """ This is my another file we have mode as 'w' which means content replacement 
    so in future on the same file if I write anything then all the previous content will be gone 
    and fresh content written will be present in the file.
    flush() and close() once work is done."""
)
# Out:
# 277

# %%
f1.flush()
f1.close()

# %%
# write mode with replacement
f2 = open(
    file="text3.txt",
    mode="w"
)

# %%
f2.write(
    """
    This is my first content as iam using w (write + replacement) so later if i try to write on same file 
    then this will be gone....
    """
)
# Out:
# 143

# %%
# 143 characters have been writeen to text3.txt/f2 now flush & close
f2.flush()
f2.close()

# %%
# now i will be writting to the same file again
# f2 - opened and closed , so again open it to work
f2 = open(
    file="text3.txt" , 
    mode="w"
)

# %%
f2.write(
    "This is my new content"
)
# Out:
# 22

# %%
f2.flush()
f2.close()

# %%
# write multiple line to a file 
lines = [
    "This is my 1st line\n" , 
    "This is my 2nd line\n" ,
    "This is my 3rd line\n" ,
    "This is my 4th line"
]
f3 = open(
    file="text3.txt",
    mode="w" # write + replacement
)

# %%
f3.writelines(lines) # writelines(list)

# %%
f3.flush()
f3.close()

# %%
# write + append functionality 
f4 = open(
    file="text4.txt" ,
    mode="a"
)

# %%
f4.write(
    "This is my first content"
)
# Out:
# 24

# %%
f4.flush()
f4.close()

# %%
f4 = open(
    file="text4.txt" ,
    mode="a"
)

# %%
f4.writelines(lines)

# %%
f4.flush()
f4.close()

# %%
# reading from the file

# %%
# %ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 08-12-2025  08:57    <DIR>          .
# 06-12-2025  11:12    <DIR>          ..
# 08-12-2025  08:57    <DIR>          .ipynb_checkpoints
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
f1 = open(
    file="text1.txt" ,
    mode="r"
)

# %%
text1 = f1.read()
f1.flush()
f1.close()

# %%
text1
# Out:
# 'This is my first file operation using python'

# %%
f2 = open(
    file="text2.txt"
)

# %%
# no mode default is read mode

# %%
text2 = f2.read()
f2.flush()
f2.close()

# %%
text2
# Out:
# " This is my another file we have mode as 'w' which means content replacement \n    so in future on the same file if I write anything then all the previous content will be gone \n    and fresh content written will be present in the file.\n    flush() and close() once work is done."

# %%
f1 = open(
    file="text1.txt"
)

# %%
# mode is read
text1 = f1.read()

# %%
text2 = f1.read()

# %%
f1.flush()
f1.close()

# %%
text1
# Out:
# 'This is my first file operation using python'

# %%
text2
# Out:
# ''

# %%
# text2 is blank bcz when we read for text1 then the pointer have already reached to the end of the file.

# %%
# reseting the pointer position
# file.seek(index) -> place the pointer at that index.

# %%
f1 = open(
    file="text1.txt"
)

# %%
text1 = f1.read()

# %%
f1.seek(0)
# Out:
# 0

# %%
text2 = f1.read()

# %%
f1.flush()
f1.close()

# %%
text1
# Out:
# 'This is my first file operation using python'

# %%
text2
# Out:
# 'This is my first file operation using python'

# %%
# get pointers position
# file.tell() - returns the position of the pointer

# %%
f1 = open(
    file="text1.txt"
)

# %%
text1 = f1.read()

# %%
text1
# Out:
# 'This is my first file operation using python'

# %%
f1.tell()
# Out:
# 44

# %%
text2 = f1.read()

# %%
text2
# Out:
# ''

# %%
f1.seek(0)
# Out:
# 0

# %%
f1.tell()
# Out:
# 0

# %%
text2 = f1.read()

# %%
text2
# Out:
# 'This is my first file operation using python'

# %%
f1.tell()
# Out:
# 44

# %%
f1.flush()
f1.close()

# %%
# readline -> reads one line based on \n and return a string.
# readlines -> reads line by line based on \n and returns a list of strings.
# r+/w+ mode -> read + write mode

# %%
f1 = open(
    file="text3.txt" ,
    mode= "r+"
)

# %%
f1.read()
# Out:
# 'This is my 1st line\nThis is my 2nd line\nThis is my 3rd line\nThis is my 4th line'

# %%
f1.tell()
# Out:
# 82

# %%
f1.seek(0)
# Out:
# 0

# %%
f1.readline()
# Out:
# 'This is my 1st line\n'

# %%
f1.readline()
# Out:
# 'This is my 2nd line\n'

# %%
f1.readline()
# Out:
# 'This is my 3rd line\n'

# %%
f1.readline()
# Out:
# 'This is my 4th line'

# %%
f1.readline()
# Out:
# ''

# %%
f1.seek(0)
# Out:
# 0

# %%
r_lines = f1.readlines() # returns list of lines

# %%
r_lines
# Out:
# ['This is my 1st line\n',
#  'This is my 2nd line\n',
#  'This is my 3rd line\n',
#  'This is my 4th line']

# %%
f1.tell()
# Out:
# 82

# %%
f1.seek(0)
# Out:
# 0

# %%
f1.readlines()
# Out:
# ['This is my 1st line\n',
#  'This is my 2nd line\n',
#  'This is my 3rd line\n',
#  'This is my 4th line']

# %%
f1.tell()
# Out:
# 82

# %%
f1.seek(0)
# Out:
# 0

# %%
f1.close()

# %%
f1 = open(
    file="text4.txt" ,
    mode="r+"
)

# %%
f1.read()
# Out:
# 'This is my first contentThis is my 1st line\nThis is my 2nd line\nThis is my 3rd line\nThis is my 4th line'

# %%
f1.seek(0)
# Out:
# 0

# %%
f1.readline() # -> This is my first contentThis is my 1st line\n
# Out:
# 'This is my first contentThis is my 1st line\n'

# %%
f1.readlines()
# Out:
# ['This is my 2nd line\n', 'This is my 3rd line\n', 'This is my 4th line']

# %%
f1.close()

# %%
f1 = open(
    file="text4.txt" ,
    mode="r+"
)

# %%
for line in f1.readlines():
    print(line , end=" ")

f1.flush()
f1.close()
# Out:
# This is my first contentThis is my 1st line
#  This is my 2nd line
#  This is my 3rd line
#  This is my 4th line

# %%
# no of lines in a file
f1 = open(
    file="text4.txt" ,
    mode="r+"
)

# %%
lines = f1.readlines()
len(lines)
# Out:
# 4

# %%
f1.close()

# %%
# list of all the words in the first paragraph
f1 = open(
    file="text4.txt" ,
    mode="r+"
)

# %%
p_lines = f1.readlines()
p_lines
# Out:
# ['This is my first contentThis is my 1st line\n',
#  'This is my 2nd line\n',
#  'This is my 3rd line\n',
#  'This is my 4th line']

# %%
words = p_lines[0].split()
words
# Out:
# ['This', 'is', 'my', 'first', 'contentThis', 'is', 'my', '1st', 'line']

# %%
# 1st character of each word 
def first_character(l_words):
    for i in l_words:
        yield i[0]

for i in first_character(words):
    print(i)
# Out:
# T
# i
# m
# f
# c
# i
# m
# 1
# l

# %%
f1.close()

# %%
# os module

# %%
# delete a file 
# %ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 08-12-2025  08:57    <DIR>          .
# 06-12-2025  11:12    <DIR>          ..
# 08-12-2025  08:57    <DIR>          .ipynb_checkpoints
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
import os

os.remove("text2.txt")

# %%
# %ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 08-12-2025  08:57    <DIR>          .
# 06-12-2025  11:12    <DIR>          ..
# 08-12-2025  08:57    <DIR>          .ipynb_checkpoints
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
# present working directory
os.getcwd()
# Out:
# 'E:\\FSDS\\Python'

# %%
# %pwd
# Out:
# 'E:\\FSDS\\Python'

# %%
# list of all the files
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'FSDS_L01_Intro.ipynb',
#  'FSDS_L02_Intro.ipynb',
#  'FSDS_L03_Basics.ipynb',
#  'FSDS_L04_String_List.ipynb',
#  'FSDS_L05_Tuple_Set_Dict.ipynb',
#  'FSDS_L06_ConditionalStatement_ForLoop.ipynb',
#  'FSDS_L07_break_continue_whileloop_range.ipynb',
#  'FSDS_L08_Practice_01.ipynb',
#  'FSDS_L09_Functions_practice.ipynb',
#  'FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb',
#  'FSDS_L10_02_iterable_vs_iterator.ipynb',
#  'FSDS_L11_01_generator_yield.ipynb',
#  'FSDS_L11_02_FileHandling.ipynb',
#  'text1.txt',
#  'text3.txt',
#  'text4.txt']

# %%
# in the current working directory how many python files & text files we have 
files_cwd = os.listdir()
python_files = 0
text_files = 0

for i in files_cwd :
    if(i.endswith('.ipynb')):
        python_files += 1
    elif(i.endswith('.txt')):
        text_files += 1

print('01_Python files count : ' , python_files , " and Text files count : " , text_files )
# Out:
# Python files count :  13  and Text files count :  3

# %%
# list of all the files
# os.listdir(location) -> location : default is pwd else we can give any other locations
os.listdir("/01_Python\\.ipynb_checkpoints")
# Out:
# ['FSDS_L01_Intro-checkpoint.ipynb',
#  'FSDS_L02_Intro-checkpoint.ipynb',
#  'FSDS_L03_Basics-checkpoint.ipynb',
#  'FSDS_L04_String_List-checkpoint.ipynb',
#  'FSDS_L05_Tuple_Set_Dict-checkpoint.ipynb',
#  'FSDS_L06_ConditionalStatement_ForLoop-checkpoint.ipynb',
#  'FSDS_L07_break_continue_whileloop_range-checkpoint.ipynb',
#  'FSDS_L08_Practice_01-checkpoint.ipynb',
#  'FSDS_L09_Functions_practice-checkpoint.ipynb',
#  'FSDS_L10_01_args_kwargs_lambdas_comprehensions-checkpoint.ipynb',
#  'FSDS_L10_02_iterable_vs_iterator-checkpoint.ipynb',
#  'FSDS_L11_01_generator_yield-checkpoint.ipynb',
#  'FSDS_L11_02_FileHandling-checkpoint.ipynb']

# %%
os.getcwd()
# Out:
# 'E:\\FSDS\\Python'
