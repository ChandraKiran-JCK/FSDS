# %%
# modules

# %%
import os

# os -> module
# so will learn how to create our own modules and import them.
# module based coding -> standard & code-reusability.

# %%
# type()
# print()
# len()

# these function are written by some-one and we are able to use them. how? -> modular coding.

# %%
pwd
# Out:
# 'E:\\FSDS\\Python'

# %%
# in this location create a .py file

# %%
ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 12-12-2025  08:14    <DIR>          .
# 12-12-2025  08:08    <DIR>          ..
# 11-12-2025  20:31    <DIR>          .ipynb_checkpoints
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
# after creating the file write the logic into that file.

# %%
ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 12-12-2025  08:14    <DIR>          .
# 12-12-2025  08:08    <DIR>          ..
# 11-12-2025  20:31    <DIR>          .ipynb_checkpoints
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
testAdd(4,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 testAdd(4,5)
#
# NameError: name 'testAdd' is not defined

# %%
import mod1

# %%
mod1.testAdd(4,5)
# Out:
# 9

# %%
mod1.testAdd(3,4)
# Out:
# 7

# %%
ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 12-12-2025  08:26    <DIR>          .
# 12-12-2025  08:08    <DIR>          ..
# 12-12-2025  07:42    <DIR>          .ipynb_checkpoints
# 12-12-2025  08:26    <DIR>          __pycache__
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
import mod1

# %%
mod1.testSub(5,3)
# Out:
# 2

# %%
mod1.testMul(2,5)
# Out:
# 10

# %%
mod1.testDiv(2,5)
# Out:
# 0.4

# %%
mod1.testLength("dfgh")
# Out:
# 4

# %%
mod1.testAdd(4,5)
# Out:
# 9

# %%
# in above case if we import a module then by-default all the methods will be imported.
# to import a specific method from a module.
from mod1 import testAdd

# %%
testAdd(4,5)
# Out:
# 9

# %%
from mod1 import testMul , testLength

# %%
testMul(4,5)
# Out:
# 20

# %%
testLength("dfg")
# Out:
# 3

# %%
# to import all the methods from a module(mod1) :
# import mod1
# from mod1 import *

# %%
from mod1 import *

# %%
# now all the methods are imported so i can use all of them

# %%
print(testAdd(4,5))
print(testSub(4,5))
print(testMul(4,5))
print(testDiv(4,5))
print(testLength("fgh"))
# Out:
# 9
# -1
# 20
# 0.8
# 3

# %%
ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 12-12-2025  08:42    <DIR>          .
# 12-12-2025  08:08    <DIR>          ..
# 12-12-2025  07:42    <DIR>          .ipynb_checkpoints
# 12-12-2025  08:26    <DIR>          __pycache__
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
mod1.testAdd(4,5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 mod1.testAdd(4,5)
#
# NameError: name 'mod1' is not defined

# %%
import mod1

# %%
mod1.testAdd(4,5)
# Out:
# 9

# %%
mod1.testSub(4,5)
# Out:
# -1

# %%
mod1.testLength("ghj")
# Out:
# 3

# %%
mod1.testMul(4,5)
# Out:
# 20

# %%
mod1.testDiv(4,5)
# Out:
# 0.8

# %%
from mod1 import *

# %%
testAdd(4,5)
# Out:
# 9

# %%
testSub(4,5)
# Out:
# -1

# %%
testLength("ghj")
# Out:
# 3

# %%
testMul(4,5)
# Out:
# 20

# %%
testDiv(4,5)
# Out:
# 0.8

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_2',
#  '_3',
#  '_4',
#  '_5',
#  '_6',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'open',
#  'quit',
#  'testAdd',
#  'testDiv',
#  'testLength',
#  'testMul',
#  'testSub']

# %%
# create a new module

# %%
pwd
# Out:
# 'E:\\FSDS\\Python'

# %%
ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 12-12-2025  09:12    <DIR>          .
# 12-12-2025  08:08    <DIR>          ..
# 12-12-2025  07:42    <DIR>          .ipynb_checkpoints
# 12-12-2025  08:48    <DIR>          __pycache__
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
open(
    file="my_module.py" , 
    mode="w"
)
# Out:
# <_io.TextIOWrapper name='my_module.py' mode='w' encoding='cp1252'>

# %%
ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 12-12-2025  09:13    <DIR>          .
# 12-12-2025  08:08    <DIR>          ..
# 12-12-2025  07:42    <DIR>          .ipynb_checkpoints
# 12-12-2025  08:48    <DIR>          __pycache__
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 12-12-2025  09:14    <DIR>          .
# 12-12-2025  08:08    <DIR>          ..
# 12-12-2025  07:42    <DIR>          .ipynb_checkpoints
# 12-12-2025  08:48    <DIR>          __pycache__
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is 2E31-A152
#
#  Directory of E:\FSDS\Python
#
# 12-12-2025  09:18    <DIR>          .
# 12-12-2025  08:08    <DIR>          ..
# 12-12-2025  07:42    <DIR>          .ipynb_checkpoints
# 12-12-2025  08:48    <DIR>          __pycache__
# 22-11-2025  08:28             1,541 FSDS_L01_Intro.ipynb
# 23-11-2025  10:48             1,201 FSDS_L02_Intro.ipynb
# 29-11-2025  06:06            22,982 FSDS_L03_Basics.ipynb
# 29-11-2025  06:06            63,158 FSDS_L04_String_List.ipynb
# 03-12-2025  21:09            32,427 FSDS_L05_Tuple_Set_Dict.ipynb
# 02-12-2025  07:01            23,058 FSDS_L06_ConditionalStatement_ForLoop.ipynb
# 03-12-2025  07:20            16,898 FSDS_L07_break_continue_whileloop_range.ipynb
# 03-12-2025  21:54            10,299 FSDS_L08_Practice_01.ipynb
# 04-12-2025  22:43            32,446 FSDS_L09_Functions_practice.ipynb
# 06-12-2025  11:08            39,235 FSDS_L10_01_args_kwargs_lambdas_comprehensions.ipynb
# ...

# %%
greeting_msg()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 greeting_msg()
#
# NameError: name 'greeting_msg' is not defined

# %%
import my_module

# %%
my_module.get_name()
# Out:
# 'chandra'

# %%
my_module.get_course()
# Out:
# ['data science', 'ML', 'AI', 'MLOPS']

# %%
my_module.greeting_msg()
# Out:
# 'welocome message from chandra !!'

# %%
from my_module import *

# %%
get_name()
# Out:
# 'chandra'

# %%
get_course()
# Out:
# ['data science', 'ML', 'AI', 'MLOPS']

# %%
greeting_msg()
# Out:
# 'welocome message from chandra !!'

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_11',
#  '_17',
#  '_18',
#  '_19',
#  '_2',
#  '_21',
#  '_22',
#  '_23',
#  '_3',
#  '_4',
#  '_5',
#  '_6',
#  '_7',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__session__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'data_dict',
#  'exit',
#  'get_course',
#  'get_ipython',
#  'get_name',
#  'greeting_msg',
#  'my_module',
#  'open',
#  'quit',
#  'testAdd',
#  'testDiv',
#  'testLength',
#  'testMul',
#  'testSub']

# %%
# module -> its a .py file, collection of functions.
# package -> its a folder,  collection of modules.

# %%
# shift to pycharm
