# %%
# lecture 1 introduction 
1. dashboard & live class link access , previous batch lectures.
2. syllabus ( python , stats , ML , DL , NLP , DA , Big Data , ML Ops , Cloud , DSA , Architecture , Databases).
3. projects (56+).
4. Ineuron services(lifetime access/doubt support/internship.....).
5. Internships.
    a. project structure (problem statement/data set/data bases...)
    b. submission (HLD , LLD , SOURCE CODE(git) , Architecture , wireframes ....)
6. Ineuron success stories.
7. Interview preparation resource -> "https://github.com/iNeuronai/interview-question-data-science-"

# motivation / confidence / consistency / practice & preparation.
